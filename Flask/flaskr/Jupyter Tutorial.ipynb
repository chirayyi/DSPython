# %% [markdown]
# # MatplotLib Example

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
line, = plt.plot([1,2,3,4], [1,4,9,16], lw=2)
plt.axis([0, 6, 0, 20])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[4,5,6,7],lw=2)
plt.show()
